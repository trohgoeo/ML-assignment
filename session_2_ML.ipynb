# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/top10s.csv", encoding='latin1')
print(df.head())
print(df.tail())
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78
#      Unnamed: 0                                              title  \
# 598         599                Find U Again (feat. Camila Cabello)
# ...

# %%
X = df.drop(columns=["pop"])

# %%
X = df.drop(columns=["Unnamed: 0", "pop"])

# %%
y = df["pop"]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=["Unnamed: 0", "pop"])
y = df["pop"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))
# Out:
# Training rows: 482
# Testing rows: 121

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("/content/sample_data/top10s.csv", encoding="latin1")

# Feature
X = df[["dnce"]]

# Target
y = df["pop"]

# 5% training and 95% testing
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.05,
    test_size=0.95,
    random_state=42
)

model = LinearRegression()

model.fit(X_train, y_train)

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

print("Train R²:", r2_score(y_train, train_pred))
print("Test R² :", r2_score(y_test, test_pred))

print("Train MSE:", mean_squared_error(y_train, train_pred))
print("Test MSE :", mean_squared_error(y_test, test_pred))
# Out:
# Train R²: 0.00830907644774237
# Test R² : 0.012124754102330493
# Train MSE: 187.1651336384294
# Test MSE : 208.97083698714448

# %% [markdown]
# ![im-graph.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# --High Bias (Underfitting): The model is too simple and misses important patterns, leading to high errors on both training and testing data.
# --Balanced Model: The model captures useful patterns and generalizes well to new data.
# --High Variance (Overfitting): The model memorizes the training data, performs very well on training data, but poorly on new, unseen data.

# %% [markdown]
# -- in instagram it only show like if we like any reel it only show that type of reel instead of our interesting parts.
