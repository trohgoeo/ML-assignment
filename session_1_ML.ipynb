# %% [markdown]
# Q-1. List three apps you use daily (such as Zomato, Instagram, or Flipkart) and describe one feature in each app that likely uses /machine learning. For each, state whether it is an example of supervised, unsupervised, or reinforcement learning.
# -- Email:- supervised(i use email everyday where we check spam and not spam.)
# -- netflix:-unsupervised(it recommand movies/series based on some trend.)
# -- ipo:-reinforcement(if you know then you will get money but not know then not get any money.)
#
# Q-2.Given the following scenarios, classify each as supervised, unsupervised, or reinforcement learning: 1) Netflix recommending movies based on your watch history, 2) Spotify grouping similar songs into playlists, 3) A self-driving car learning to park by trial and error. Write your answers with a one-line explanation for each choice.
# -- 1) unsupervised-it grouping things then give predict what to see 2) unsupervised- it like groups songs of same song like trendy 3) reinforcement -if you learn good park good but if not then you crash car.
#
# Q-3.Draw a simple diagram (hand-drawn or digital) showing the basic ML workflow: Data → Preprocessing → Modeling → Evaluation → Deployment. Under each step, write a one-line example of what happens at that stage for a food delivery app like Swiggy.
# -- 1.problem understand:-what is the que and understand it first
# 2. data collection: decide what data take based on problem or what you want to predict
# 3. data preprocessing : clean data like missing values,check outliers,transform data
# 4. feature engineering : scaling ,feature selection
# 5. train_test_split : to learn the pattern of data which model is doing that to check performance
# 6. predict : predict value of test or new data
# 7. evaluate : check error for test and train how model perform on noth data by checking mse,rmse,r2
# 8. deployment: model is perfect or ready to deploy
#
# Q-4.Imagine you are building a spam filter for WhatsApp messages. Write a short paragraph explaining how traditional programming would approach this problem versus how machine learning would approach it.<br><br><em><strong>Hint:</strong> Focus on rules vs learning from data.</em>
# -- traditional: it use logic or if else statement for spam filtering like if user know or mail is registered then it not go on spam if not then it is spam
# -- machine learning: it uses find pattern from thousands of dataset of email based on it give spam or not spam like predict.
